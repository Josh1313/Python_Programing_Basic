# %%
print('''
*******************************************************************************
          |                   |                  |                     |
 _________|________________.=""_;=.______________|_____________________|_______
|                   |  ,-"_,=""     `"=.|                  |
|___________________|__"=._o`"-._        `"=.______________|___________________
          |                `"=._o`"=._      _`"=._                     |
 _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
|                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
|___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
          |           |o`"=._` , "` `; .". ,  "-._"-._; ;              |
 _________|___________| ;`-.o`"=._; ." ` '`."\` . "-._ /_______________|_______
|                   | |o;    `"-.o`"=._``  '` " ,__.--o;   |
|___________________|_| ;     (#) `-.o `"=.`_.--"_o.-; ;___|___________________
____/______/______/___|o;._    "      `".o|o_.--"    ;o;____/______/______/____
/______/______/______/_"=._o--._        ; | ;        ; ;/______/______/______/_
____/______/______/______/__"=._o--._   ;o|o;     _._;o;____/______/______/____
/______/______/______/______/____"=._o._; | ;_.--"o.--"_/______/______/______/_
____/______/______/______/______/_____"=.o|o_.--""___/______/______/______/____
/______/______/______/______/______/______/______/______/______/______/_____ /
*******************************************************************************
''')
print("Welcome to Treasure Island.")
print("Your mission is to find the treasure.")

#Write your code below this line 👇

choice1 = input('You\'re at a cross road. Where do you want to go? Type "left" or "right" \n').lower()
if choice1 == "left":
  choice2 = input('You\'ve come to a lake. There is an island in the middle of the lake. Type "wait" to wait for a boat. Type "swim" to swim across. \n').lower()
  if choice2 == "wait":
    choice3 = input("You arrive at the island unharmed. There is a house with 3 doors. One red, one yellow and one blue. Which colour do you choose? \n").lower()
    if choice3 == "red":
      print("It's a room full of fire. Game Over.")
    elif choice3 == "yellow":
      print("You found the treasure! You Win!")
    elif choice3 == "blue":
      print("You enter a room of beasts. Game Over.")
    else:
      print("You chose a door that doesn't exist. Game Over.")
  else:
    print("You get attacked by an angry trout. Game Over.")
else:
  print("You fell into a hole. Game Over.")

# %%
print("The Love Calculator is calculating your score...")
name1 = input("What is your name?") # What is your name?
name2 = input("What is their name?") # What is their name?
# 🚨 Don't change the code above 👆
# Write your code below this line 👇
# Combine both names and convert to lowercase
combined_names = (name1 + name2).lower()

# Count occurrences of each letter in 'TRUE'
t_count = combined_names.count('t')
r_count = combined_names.count('r')
u_count = combined_names.count('u')
e_count = combined_names.count('e')
true_count = t_count + r_count + u_count + e_count

# Count occurrences of each letter in 'LOVE'
l_count = combined_names.count('l')
o_count = combined_names.count('o')
v_count = combined_names.count('v')
e_count = combined_names.count('e')
love_count = l_count + o_count + v_count + e_count

# Combine the counts to form the love score
love_score = int(f"{true_count}{love_count}")

# Display the appropriate message based on the love score
if love_score < 10 or love_score > 90:
    print(f"Your score is {love_score}, you go together like coke and mentos.")
elif 40 <= love_score <= 50:
    print(f"Your score is {love_score}, you are alright together.")
else:
    print(f"Your score is {love_score}.")

# %%
print("The Love Calculator is calculating your score...")
name1 = input("What is your name?") # What is your name?
name2 = input("What is their name?") # What is their name?
# 🚨 Don't change the code above 👆
# Write your code below this line 👇
# Combine both names and convert to lowercase
combined_names = (name1 + name2).lower()

# Count occurrences of each letter in 'TRUE'
t_count = combined_names.count('t')
r_count = combined_names.count('r')
u_count = combined_names.count('u')
e_count = combined_names.count('e')
true_count = t_count + r_count + u_count + e_count

# Count occurrences of each letter in 'LOVE'
l_count = combined_names.count('l')
o_count = combined_names.count('o')
v_count = combined_names.count('v')
e_count = combined_names.count('e')
love_count = l_count + o_count + v_count + e_count

# Combine the counts to form the love score
love_score = int(f"{true_count}{love_count}")

# Display the appropriate message based on the love score
if love_score < 10 or love_score > 90:
    print(f"Your score is {love_score}, you go together like coke and mentos.")
elif 40 <= love_score <= 50:
    print(f"Your score is {love_score}, you are alright together.")
else:
    print(f"Your score is {love_score}.")

# %%
print("Thank you for choosing Python Pizza Deliveries!")
size = input("  What size pizza do you want? S, M, or L")  
add_pepperoni = input("Do you want pepperoni? Y or N") 
extra_cheese = input("Do you want extra cheese? Y or N")  

# Initialize bill
bill = 0

# Calculate base price based on size
if size == "S":
    bill += 15
elif size == "M":
    bill += 20
else:
    bill += 25

# Add pepperoni cost if required
if add_pepperoni == "Y":
    if size == "S":
        bill += 2
    else:
        bill += 3

# Add cheese cost if required
if extra_cheese == "Y":
    bill += 1

# Print the final bill
print(f"Your final bill is: ${bill}.")

# %%
print(" bienvenidos a Josue calculadora de cuenta y propina")
# aca pensando que devolveremos un decimal lo cambiaremos a decimal
cuenta = int(input("cual es el total de la cuenta"))
# aca pensando que devolveremos un decimal lo cambiaremos a decimal
propina = int(input(" cuantos es el porcentaje de propina que deseas dejar? 10,12,15,20"))
# aca pensando que devolveremos un decimal lo cambiaremos a decimal
comensales = int(input("entre cuantas personas repartiran la cuenta?"))
# desde aca pensaremos las mates que utilizaremos
propina_porcentaje = propina / 100
total_propina_en_porcentaje = cuenta * propina_porcentaje
total_de_la_cuenta = cuenta + total_propina_en_porcentaje
cuenta_po_persona = total_de_la_cuenta / comensales
total_final = round(cuenta_po_persona, 2)
total_final = "{:.2f}".format(cuenta_po_persona)
print(f"cada persona debe pagar: {total_final}")

# %%
print('bienvenidos a josh brandName')
nombre=input("ingresa tu nombre,\n")
ciudad = input("donde vives, \n")
sibling = input("ingresa el nombre de tus padres,\n")
respuesta = print(ciudad + '\t' + sibling)

# %%
from datetime import datetime, timedelta

# Function to check if a year is a leap year
def is_leap_year(year: int) -> bool:
    if year % 4 == 0:
        if year % 100 == 0:
            if year % 400 == 0:
                return True
            else:
                return False
        else:
            return True
    else:
        return False

# Function to add days, hours, and minutes to a given date
def add_time_to_date(year: int, month: int, day: int, hour: int, minute: int, add_days: int, add_hours: int, add_minutes: int):
    date = datetime(year, month, day, hour, minute)
    delta = timedelta(days=add_days, hours=add_hours, minutes=add_minutes)
    new_date = date + delta
    return new_date

# Function to adjust for the equation of time (simple approximation)
def adjust_for_equation_of_time(date: datetime) -> datetime:
    # Equation of time approximation (in minutes)
    # For simplicity, we use a sine function to simulate the variation throughout the year
    # Actual equation is more complex, but this serves as a rough approximation
    day_of_year = date.timetuple().tm_yday
    E = 7.5 * math.sin(2 * math.pi * (day_of_year - 81) / 365)
    return date + timedelta(minutes=E)

# Example usage
import math

year = int(input("Enter the year: "))
month = int(input("Enter the month: "))
day = int(input("Enter the day: "))
hour = int(input("Enter the hour (24-hour format): "))
minute = int(input("Enter the minute: "))
add_days = int(input("Enter the number of days to add: "))
add_hours = int(input("Enter the number of hours to add: "))
add_minutes = int(input("Enter the number of minutes to add: "))

if is_leap_year(year):
    print(f"The year {year} is a leap year.")
else:
    print(f"The year {year} is not a leap year.")

# Calculate new date and time
new_date = add_time_to_date(year, month, day, hour, minute, add_days, add_hours, add_minutes)
print(f"New date and time after adding: {new_date.strftime('%Y-%m-%d %H:%M')}")

# Adjust for the equation of time
adjusted_date = adjust_for_equation_of_time(new_date)
print(f"Adjusted date and time (solar time): {adjusted_date.strftime('%Y-%m-%d %H:%M')}")

# %%
# Which year do you want to check?
year = int(input())

if year % 4 == 0:
  if year % 100 == 0:
    if year % 400 == 0:
      print("Leap year")
    else:
      print("Not leap year")
  else:
    print("Leap year")
else:
  print("Not leap year")

# %%
import pandas as pd
import math

# Número inicial
numero_inicial = 8
potencia = 0.025
valor_inicial =  0.65834



# Calcular la primera raíz cuadrada
raiz_0 = (numero_inicial)
raiz_1 = math.sqrt(numero_inicial)
raiz_2 = math.sqrt(raiz_1)
raiz_3 = math.sqrt(raiz_2)
raiz_4 = math.sqrt(raiz_3)
raiz_5 = math.sqrt(raiz_4)
raiz_6 = math.sqrt(raiz_5)
raiz_7 = math.sqrt(raiz_6)
raiz_8 = math.sqrt(raiz_7)
raiz_9 = math.sqrt(raiz_8)
raiz_10 = math.sqrt(raiz_9)
raiz_11 = math.sqrt(raiz_10)

# Calcular la octava raíz cuadrada
raiz_29 = math.sqrt(raiz_8)

# Elevar la raíz cuadrada a la potencia de 0.025
resultado_potencia0 = raiz_0 ** potencia 
resultado_potencia1 = raiz_1 ** potencia 
resultado_potencia2 = raiz_2 ** potencia 
resultado_potencia3 = raiz_3 ** potencia 
resultado_potencia4 = raiz_4 ** potencia 
resultado_potencia5 = raiz_5 ** potencia 
resultado_potencia6 = raiz_6 ** potencia 
resultado_potencia7 = raiz_7 ** potencia 
resultado_potencia8 = raiz_8 ** potencia 
resultado_potencia9 = raiz_9 ** potencia 
resultado_potencia10 = raiz_10 ** potencia 
resultado_potencia11 = raiz_11 ** potencia 



# Multiplicar por 0.63620
resultado_0 = resultado_potencia0 * valor_inicial
resultado_1 = resultado_potencia1 * valor_inicial
resultado_2 = resultado_potencia2 * valor_inicial
resultado_3 = resultado_potencia3 * valor_inicial
resultado_4 = resultado_potencia4 * valor_inicial
resultado_5 = resultado_potencia5 * valor_inicial
resultado_6 = resultado_potencia6 * valor_inicial
resultado_7 = resultado_potencia7 * valor_inicial
resultado_8 = resultado_potencia8 * valor_inicial
resultado_9 = resultado_potencia9 * valor_inicial
resultado_10 = resultado_potencia10 * valor_inicial
resultado_11 = resultado_potencia11 * valor_inicial


# Crear un DataFrame para almacenar los resultados
df = pd.DataFrame({
    'Paso': ['Potencia','Raíz cuadrada 1', 'Raíz cuadrada 2', 'Raíz cuadrada 3','Raíz cuadrada 4', 'Raíz cuadrada 5', 'Raíz cuadrada 6', 'Raíz cuadrada 7', 'Raíz cuadrada 8', 'Raíz cuadrada 9', 'Raíz cuadrada 10', 'Raíz cuadrada 11','Valor Inicial'],
    'Valor': [ resultado_0, resultado_1, resultado_2, resultado_3, resultado_4, resultado_5, resultado_6, resultado_7, resultado_8,resultado_9, resultado_10, resultado_11, valor_inicial]
})

# Mostrar el DataFrame
print(df)

# %%
# precio a fecha convertirlo a entero
precio = 8.9
precio_decimal = precio * 10
precio_entero = 10
truncated_precio = int(precio_decimal * 10) / 10.0
print(truncated_precio)  # Salida: 6.5
nuevo_precio_entero = precio / precio_entero

# Días totales
total_days = 6.58



print(total_days)


# Parte entera: días completos
complete_days = int(total_days)

# Parte decimal: fracción de un día
fractional_day = total_days - complete_days

# Convertir la fracción de día a horas, minutos y segundos
total_hours = fractional_day * 24
complete_hours = int(total_hours)

fractional_hour = total_hours - complete_hours
total_minutes = fractional_hour * 60
complete_minutes = int(total_minutes)

fractional_minute = total_minutes - complete_minutes
total_seconds = fractional_minute * 60
complete_seconds = int(total_seconds)

print(f"Días completos: {complete_days}")
print(f"Horas: {complete_hours}")
print(f"Minutos: {complete_minutes}")
print(f"Segundos: {complete_seconds:.2f}")

# %%
from datetime import datetime, timedelta

# Function to check if a year is a leap year
def is_leap_year(year: int) -> bool:
    if year % 4 == 0:
        if year % 100 == 0:
            if year % 400 == 0:
                return True
            else:
                return False
        else:
            return True
    else:
        return False

# Function to add days, hours, and minutes to a given date
def add_time_to_date(year: int, month: int, day: int, hour: int, minute: int, add_days: int, add_hours: int, add_minutes: int):
    date = datetime(year, month, day, hour, minute)
    delta = timedelta(days=add_days, hours=add_hours, minutes=add_minutes)
    new_date = date + delta
    return new_date

# Function to adjust for the equation of time (simple approximation)
def adjust_for_equation_of_time(date: datetime) -> datetime:
    # Equation of time approximation (in minutes)
    # For simplicity, we use a sine function to simulate the variation throughout the year
    # Actual equation is more complex, but this serves as a rough approximation
    day_of_year = date.timetuple().tm_yday
    E = 7.5 * math.sin(2 * math.pi * (day_of_year - 81) / 365)
    return date + timedelta(minutes=E)

# Example usage
import math

year = int(input("Enter the year: "))
month = int(input("Enter the month: "))
day = int(input("Enter the day: "))
hour = int(input("Enter the hour (24-hour format): "))
minute = int(input("Enter the minute: "))
add_days = int(input("Enter the number of days to add: "))
add_hours = int(input("Enter the number of hours to add: "))
add_minutes = int(input("Enter the number of minutes to add: "))

if is_leap_year(year):
    print(f"The year {year} is a leap year.")
else:
    print(f"The year {year} is not a leap year.")

# Calculate new date and time
new_date = add_time_to_date(year, month, day, hour, minute, add_days, add_hours, add_minutes)
print(f"New date and time after adding: {new_date.strftime('%Y-%m-%d %H:%M')}")

# Adjust for the equation of time
adjusted_date = adjust_for_equation_of_time(new_date)
print(f"Adjusted date and time (solar time): {adjusted_date.strftime('%Y-%m-%d %H:%M')}")
